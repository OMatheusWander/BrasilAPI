# %% [markdown]
# <a href="https://colab.research.google.com/github/OMatheusWander/BrasilAPI/blob/master/Aula_03_De_Ci%C3%AAncia_de_Dados_para_Economistas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
TAMANHO = 4
tabela= np.zeros((TAMANHO, TAMANHO), dtype = int)
tabela[:, 0] = np.random.randint(1, 170, TAMANHO)
tabela[:, 1] = np.random.randint(1, 170, TAMANHO)
tabela[:, 2] = np.random.randint(1, 170, TAMANHO)
tabela[:, 3] = np.random.randint(1, 170, TAMANHO)
tabela
# Out:
# array([[  8, 149, 147,  91],
#        [ 85, 147, 169, 125],
#        [164,  72,   3, 132],
#        [ 91,  12, 134,  89]])

# %%
matriz_aleatoria = np.random.random((3,3))

# %%
matriz_aleatoria
# Out:
# array([[0.78732134, 0.82792703, 0.291426  ],
#        [0.69764872, 0.26556183, 0.66343059],
#        [0.61905374, 0.73314385, 0.89593953]])

# %%
lam = 1

# %%
matriz_aleatoria = np.random.poisson(lam , (1000,200))

# %%
matriz_aleatoria
# Out:
# array([[0, 1, 2, ..., 3, 3, 2],
#        [3, 1, 0, ..., 1, 1, 1],
#        [0, 1, 0, ..., 0, 2, 2],
#        ...,
#        [2, 2, 2, ..., 1, 2, 0],
#        [1, 0, 2, ..., 2, 1, 1],
#        [1, 0, 2, ..., 2, 3, 0]])

# %%
np.random.seed(5)

# %%
matriz_aleatoria
# Out:
# array([[0, 1, 2, ..., 3, 3, 2],
#        [3, 1, 0, ..., 1, 1, 1],
#        [0, 1, 0, ..., 0, 2, 2],
#        ...,
#        [2, 2, 2, ..., 1, 2, 0],
#        [1, 0, 2, ..., 2, 1, 1],
#        [1, 0, 2, ..., 2, 3, 0]])

# %%
x_barra = np.mean(matriz_aleatoria, axis=1)

# %%
x_barra
# Out:
# array([0.92 , 0.9  , 1.015, 1.21 , 0.995, 0.96 , 0.935, 0.94 , 1.005,
#        0.96 , 1.085, 1.1  , 1.09 , 1.05 , 1.005, 1.005, 0.92 , 1.005,
#        1.005, 1.08 , 0.99 , 0.89 , 1.07 , 1.08 , 0.925, 1.04 , 1.05 ,
#        1.02 , 0.935, 1.1  , 0.93 , 1.025, 1.055, 0.955, 1.16 , 1.01 ,
#        0.97 , 1.11 , 1.19 , 1.08 , 1.015, 0.94 , 1.04 , 1.095, 1.03 ,
#        0.995, 0.93 , 1.11 , 1.005, 1.115, 0.885, 0.985, 1.06 , 1.065,
#        1.015, 1.025, 1.06 , 1.14 , 1.09 , 1.05 , 1.065, 1.005, 0.96 ,
#        0.95 , 1.095, 0.965, 0.79 , 0.915, 1.025, 0.935, 0.91 , 1.02 ,
#        1.   , 1.065, 1.065, 0.805, 1.075, 0.99 , 1.02 , 1.03 , 1.09 ,
#        0.98 , 0.975, 1.045, 0.995, 1.08 , 0.95 , 1.055, 0.935, 0.92 ,
#        1.07 , 0.97 , 1.01 , 1.04 , 0.935, 0.975, 0.985, 1.015, 0.94 ,
#        1.   , 1.005, 0.98 , 1.06 , 1.08 , 0.92 , 0.88 , 1.035, 0.995,
#        1.   , 0.875, 1.03 , 0.875, 1.235, 0.94 , 0.945, 0.96 , 0.895,
# ...

# %%
x_barra1 = np.mean(matriz_aleatoria, axis = 1)

# %%
x_barra1
# Out:
# array([0.92 , 0.9  , 1.015, 1.21 , 0.995, 0.96 , 0.935, 0.94 , 1.005,
#        0.96 , 1.085, 1.1  , 1.09 , 1.05 , 1.005, 1.005, 0.92 , 1.005,
#        1.005, 1.08 , 0.99 , 0.89 , 1.07 , 1.08 , 0.925, 1.04 , 1.05 ,
#        1.02 , 0.935, 1.1  , 0.93 , 1.025, 1.055, 0.955, 1.16 , 1.01 ,
#        0.97 , 1.11 , 1.19 , 1.08 , 1.015, 0.94 , 1.04 , 1.095, 1.03 ,
#        0.995, 0.93 , 1.11 , 1.005, 1.115, 0.885, 0.985, 1.06 , 1.065,
#        1.015, 1.025, 1.06 , 1.14 , 1.09 , 1.05 , 1.065, 1.005, 0.96 ,
#        0.95 , 1.095, 0.965, 0.79 , 0.915, 1.025, 0.935, 0.91 , 1.02 ,
#        1.   , 1.065, 1.065, 0.805, 1.075, 0.99 , 1.02 , 1.03 , 1.09 ,
#        0.98 , 0.975, 1.045, 0.995, 1.08 , 0.95 , 1.055, 0.935, 0.92 ,
#        1.07 , 0.97 , 1.01 , 1.04 , 0.935, 0.975, 0.985, 1.015, 0.94 ,
#        1.   , 1.005, 0.98 , 1.06 , 1.08 , 0.92 , 0.88 , 1.035, 0.995,
#        1.   , 0.875, 1.03 , 0.875, 1.235, 0.94 , 0.945, 0.96 , 0.895,
# ...

# %%
x_normal = np.sqrt(200) * (x_barra - 1)

# %%
x_normal
# Out:
# array([-1.13137085, -1.41421356,  0.21213203,  2.96984848, -0.07071068,
#        -0.56568542, -0.91923882, -0.84852814,  0.07071068, -0.56568542,
#         1.20208153,  1.41421356,  1.27279221,  0.70710678,  0.07071068,
#         0.07071068, -1.13137085,  0.07071068,  0.07071068,  1.13137085,
#        -0.14142136, -1.55563492,  0.98994949,  1.13137085, -1.06066017,
#         0.56568542,  0.70710678,  0.28284271, -0.91923882,  1.41421356,
#        -0.98994949,  0.35355339,  0.77781746, -0.6363961 ,  2.2627417 ,
#         0.14142136, -0.42426407,  1.55563492,  2.68700577,  1.13137085,
#         0.21213203, -0.84852814,  0.56568542,  1.34350288,  0.42426407,
#        -0.07071068, -0.98994949,  1.55563492,  0.07071068,  1.6263456 ,
#        -1.6263456 , -0.21213203,  0.84852814,  0.91923882,  0.21213203,
#         0.35355339,  0.84852814,  1.97989899,  1.27279221,  0.70710678,
#         0.91923882,  0.07071068, -0.56568542, -0.70710678,  1.34350288,
# ...

# %%
np.plot(x_barra)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-255b84b6d15e> in <cell line: 1>()
# ----> 1 np.plot(x_barra)
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     309             return Tester
#     310
# --> 311         raise AttributeError("module {!r} has no attribute "
#     312                              "{!r}".format(__name__, attr))
#     313
#
# AttributeError: module 'numpy' has no attribute 'plot'

# %%
import matplotlib.pyplot as plt
plt.hist(x_normal,bins = 100, edgecolor='black')
plt.title('Histograma TLC')
plt.xlabel('x_barra')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')
